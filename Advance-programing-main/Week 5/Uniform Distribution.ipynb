# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
years = [2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020]
populations = [98.2, 100.6, 102.1, 102.8, 103.4, 104.0, 105.1, 106.5, 107.0, 108.2]

# %%
x = np.random.uniform(populations[0], populations[9], 10)

# %%
plt.plot(x)
plt.show()
